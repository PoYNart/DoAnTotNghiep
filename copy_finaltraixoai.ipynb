# %% [markdown]
# <a href="https://colab.research.google.com/github/PoYNart/DoAnTotNghiep/blob/main/copy_finaltraixoai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bai tap

# %%
# Cài đặt thư viện cần thiết
# !pip install roboflow ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 75.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 87.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 139.5 MB/s eta 0:00:00

# %% [markdown]
# YOLOv8

# %%
from roboflow import Roboflow
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ovxn4d1gqP2WILj7LvwN")
project = rf.workspace("group1tjes-zcjlu").project("mango-7cab0")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to mango-6 in yolov8:: 100%|██████████| 2922/2922 [00:00<00:00, 11016.53it/s]

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data = "/content/mango-6/data.yaml",
    epochs = 20,
    name = "smkt_scanner"
)
# Out:
#   File "/tmp/ipython-input-1174854571.py", line 6
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
show_img("/content/runs/detect/smkt_scanner/train_batch1.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2644631137.py in <cell line: 0>()
# ----> 1 show_img("/content/runs/detect/smkt_scanner/train_batch1.jpg")
#
# NameError: name 'show_img' is not defined

# %%
model = YOLO("/content/runs/detect/smkt_scanner/weights/best.pt")
model.val(split="test")

# %%
show_img("/content/runs/detect/smkt_scanner/val_batch0_labels.jpg")
show_img("/content/runs/detect/smkt_scanner/val_batch2_labels.jpg")

# %%
show_img("/content/runs/detect/smkt_scanner/train_batch1.jpg")
